# %% [markdown]
# # VNC
#
#
# ```
# sudo apt-get install tightvncserver
# vncserver :1
# ```
#
# To have start automatically, Need to mod the file
# ```
# sudo nano /etc/rc.local
# ```
#
# Above the `exit 0` add
# ```
# su - pi -c '/usr/bin/vncserver :1'
# ```
#
#
# ```
# sudo reboot
# ```
#
# Check if vnc server running after reboot with
#
# ```
# vncserver :1
# ```
#
# returns `A VNC server is already running as :1`
#
# Kill server with
# ```
# vncserver -kill :1
# ```
#
#
#
# In the end this worked
#
# Need a viewer and server
#
# Go to realvnc.com
#
# Download for Mac the viewer
#
# For pi
# ```
# sudo apt-get update
# sudo apt-get install realvnc-vnc-server
# sudo apt-get install realvnc-vnc-viewer
# ```
#
# use the mac viewer to log in to pi
#
# - Mac credentials OH
# - by default pi is pi/raspberry
#
#
# # SSH
# ```
# hostname -I
# ifconfig
#
# ssh pi@ipaddress
# ```
